# %%
from torchvision import models, transforms
import torch
from PIL import Image
import numpy as np
import os

# %%
train_dir = '../../train'
gallery_dir = '../../test-2/gallery'
query_dir = '../../test-2/query'

# %%
device = torch.device("mps" if torch.mps.is_available() else "cpu")

# Load EfficientNetB0 and remove classifier
model = models.efficientnet_b0(pretrained=True)
model.classifier = torch.nn.Identity()
model.eval().to(device)
# Out:
# /Users/anthony/Desktop/UniTrento/Courses/Second Semester/I2ML/I2ML_ImageClassifier/.conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/anthony/Desktop/UniTrento/Courses/Second Semester/I2ML/I2ML_ImageClassifier/.conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Identity()
# )

# %% [markdown]
# # Data Prep

# %%
# Preprocessing pipeline
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
def extract_feature(img_path):
    img = Image.open(img_path).convert("RGB")
    x = transform(img).unsqueeze(0).to(device)
    with torch.no_grad():
        embedding = model(x).squeeze().cpu().numpy()
    return embedding

# %%
def build_feature_index(folder_path):
    features = []
    filenames = []
    for fname in os.listdir(folder_path):
        if fname.lower().endswith(('.jpg', '.png', '.jpeg')):
            path = os.path.join(folder_path, fname)
            feat = extract_feature(path)
            features.append(feat)
            filenames.append(fname)
    return np.array(features), filenames

# %%
from sklearn.metrics.pairwise import cosine_similarity

def retrieve_top_k(query_feature, gallery_features, gallery_filenames, k=5):
    sims = cosine_similarity(query_feature.reshape(1, -1), gallery_features).flatten()
    top_k_idx = sims.argsort()[-k:][::-1]
    return [(gallery_filenames[i], sims[i]) for i in top_k_idx]

# %%
submission = dict()

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
def create_dict_submission(gallery_embeddings, query_embeddings, similarity_matrix, query_paths, gallery_paths, k: int=5):
    submission = dict()
    
    gallery_embeddings = np.vstack(gallery_embeddings)
    query_embeddings = np.vstack(query_embeddings)

    top_k = k  # You can change this to any value (e.g., 1, 3, 10)

    # Compute top-k most similar gallery indices for each query
    topk_indices = np.argsort(-similarity_matrix, axis=1)[:, :top_k]

    # Display results
    for i, indices in enumerate(topk_indices):
        print(f"\nQuery image: {query_paths[i]}")
        print("Top {} retrieved gallery images:".format(top_k))
        # finds index of the rightmost slash so that strings can be subset to only include the name
        # of the file and not the entire path leading to it
        idx_last_slash = str(query_paths[i]).rfind("/")
        submission[str(query_paths[i][idx_last_slash+1:])] = list()
        for rank, gallery_idx in enumerate(indices):
            print(f"  Rank {rank+1}: {gallery_paths[gallery_idx]}")
            # finds index of the rightmost slash so that strings can be subset to only include the name
            # of the file and not the entire path leading to it
            idx_last_slash_res = str(gallery_paths[gallery_idx]).rfind("/")
            submission[str(query_paths[i][idx_last_slash+1:])].append(gallery_paths[gallery_idx][idx_last_slash_res+1:])

    return submission

# %%
for q_feat, q_name in zip(query_features, query_filenames):
    print(f"\nQuery: {q_name}")
    top_k = retrieve_top_k(q_feat, gallery_features, gallery_filenames, k=10)
    for fname, score in top_k:
        print(f"  → {fname} (similarity: {score:.4f})")
        if q_name not in submission:
            submission[q_name] = []
        submission[q_name].append(fname)
# Out:
# Query: 4f55487a739b4d1da78c3383d7b37ea2.jpg
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6561)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6520)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.6248)
#   → a75d79ce216f4c838eef372406848f14.jpg (similarity: 0.6240)
#   → 049b584b3af9408493b432cfd9cba577.jpg (similarity: 0.6176)
#   → 35e8624e2c31435ca232d9c2ab6a963c.jpg (similarity: 0.6141)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.6065)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.5960)
#   → 8b11436b42864cfcaba961db4e6dfcd9.jpg (similarity: 0.5939)
#   → 55987960e55541a983778be2751145e0.jpg (similarity: 0.5875)
#
# Query: 06b470c625054ec4ac91d15a6808f15f.jpg
#   → 50a45e63e946442fa3a0b6efc8a5a73a.jpg (similarity: 0.5058)
#   → 57439bfcfb724b51a79380d1a7ddacb2.jpg (similarity: 0.4801)
#   → 5e0b485b44484a75bdb79651469de5b2.jpg (similarity: 0.4742)
#   → 9f2e65949b644b859d3383bac0028f86.jpg (similarity: 0.4490)
#   → 1547328594ce4bc9b2f4842a69e03292.jpg (similarity: 0.4397)
#   → 1737f3015d3d4814bfe46aa6a6298a5e.jpg (similarity: 0.4394)
#   → 3e16c04505d94bee99c53e80af01956f.jpg (similarity: 0.4382)
#   → 55987960e55541a983778be2751145e0.jpg (similarity: 0.4355)
#   → 7c3f3cae7dbd481191f246c6502b8607.jpg (similarity: 0.4339)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.4327)
#
# Query: c03793c512ae40d797aab0a23b7eb2b4.jpg
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.6747)
#   → 79734fab647a43aba11170b58533f14a.jpg (similarity: 0.6320)
#   → 0416b7f2fcb34b19893444e50f88ba3b.jpg (similarity: 0.6304)
#   → 341433edf33b46a0917657443d8d95aa.jpg (similarity: 0.6221)
#   → 19116503957b47f7b419e38f1ea93b6f.jpg (similarity: 0.6218)
#   → 10924d813ab14685aac4a50f1620be32.jpg (similarity: 0.6210)
#   → 782192d4a9ea4ff48101b051810c14d1.jpg (similarity: 0.6145)
#   → b2d4787d79dd453a9a331d1bf2b46dab.jpg (similarity: 0.6139)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6130)
#   → a5bad5611d0648ebb5518fc7ae0dcab5.jpg (similarity: 0.6085)
#
# Query: 1b340c54bfb142559b961bb3f6d82bdb.jpg
#   → 06a3c7b35b594ad9a4d5fb8591828a77.jpg (similarity: 0.5787)
#   → 3c38b9025f3145b896507fd3cf57217e.jpg (similarity: 0.5411)
#   → 8b7ca83ce58542b5a11193785b9c69d8.jpg (similarity: 0.5342)
#   → 70129aa7188a43be83559eead099832b.jpg (similarity: 0.5139)
#   → 9ace16e6eb6947a0a0d5f245743a37fc.jpg (similarity: 0.5068)
#   → 326e4e826f584c42b4edfe7fa321cb88.jpg (similarity: 0.4840)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.4768)
#   → 6965322d08d0494591cd9237ee8ded00.jpg (similarity: 0.4757)
#   → e2be29c99f724012b61590af470e8156.jpg (similarity: 0.4717)
#   → 1e537a3e2eb74086a6ca10863f74f7f2.jpg (similarity: 0.4682)
#
# Query: 31ae93cb76334e89b776c14368ee5f7b.jpg
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.5510)
#   → 3c38b9025f3145b896507fd3cf57217e.jpg (similarity: 0.5493)
#   → 4f6a3f8c9e8346d3ba8ef74a4c48b056.jpg (similarity: 0.5352)
#   → 306150c25d8042daab0acba46dac6025.jpg (similarity: 0.5329)
#   → 6965322d08d0494591cd9237ee8ded00.jpg (similarity: 0.5129)
#   → 73c30f0764d549b5b371929e364a0087.jpg (similarity: 0.5039)
#   → 4d376e7797cd4796b5ffac4fed1cf609.jpg (similarity: 0.5030)
#   → 2fdffe8cb2064babb807fba2fbbc4eab.jpg (similarity: 0.5026)
#   → 9ace16e6eb6947a0a0d5f245743a37fc.jpg (similarity: 0.4951)
#   → e6f60a23d61e4a95babd05b93931eb02.jpg (similarity: 0.4943)
#
# Query: 4de6179998e94c5a9a157c034f636617.jpg
#   → 255be13815844aca9393ec2fdc6861ab.jpg (similarity: 0.6867)
#   → 4a050c59736740599b570773a6e8c7e9.jpg (similarity: 0.6718)
#   → 63bb53a60409435fb90f48534232180e.jpg (similarity: 0.6497)
#   → e049f58a55f049afb1215cc38a146a94.jpg (similarity: 0.6486)
#   → 0416b7f2fcb34b19893444e50f88ba3b.jpg (similarity: 0.6427)
#   → a912219187564c9fbadb37efebdf9eaa.jpg (similarity: 0.6419)
#   → a5bad5611d0648ebb5518fc7ae0dcab5.jpg (similarity: 0.6374)
#   → 7e39906b7a0040119df355667929a4c0.jpg (similarity: 0.6327)
#   → a29ab68f6cdc4ba68eca29ca82eb716e.jpg (similarity: 0.6308)
#   → b81efa26a9e643028b5c3d8a0727e74b.jpg (similarity: 0.6298)
#
# Query: c0dde3c856f043aca20905ff161363cf.jpg
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6696)
#   → a75d79ce216f4c838eef372406848f14.jpg (similarity: 0.6509)
#   → 35e8624e2c31435ca232d9c2ab6a963c.jpg (similarity: 0.6424)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.6246)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6055)
#   → 98377d076a9d40af8229ea8d67c65f11.jpg (similarity: 0.5940)
#   → 5d510e7156844170b7cbc3ac98647819.jpg (similarity: 0.5902)
#   → efbd498f5c7545d7a67e6f76e98c54e4.jpg (similarity: 0.5765)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.5695)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.5678)
#
# Query: 7f4adeaf20924c9296bf09d82a3c6fef.jpg
#   → 9a5992cc77ad48dea095cfd93790cd34.jpg (similarity: 0.6131)
#   → 297a17348d83486987e946130e6b53de.jpg (similarity: 0.5347)
#   → ef586363b8914ea18c4142ce2eef95fe.jpg (similarity: 0.5289)
#   → 5f902dfcee33489787a93d0d47ff19b2.jpg (similarity: 0.5284)
#   → 07c664a8ee4c44d0bfb0b668f64b0ffb.jpg (similarity: 0.5247)
#   → ba4a48eeab94476693cc02231102ba04.jpg (similarity: 0.5204)
#   → 8a03d915a36e43ec84e56b4bea7d084c.jpg (similarity: 0.5178)
#   → 14011651632943ecaeac7f637c0c9ef1.jpg (similarity: 0.5141)
#   → b2d4d854428d4ea6aa8761e077a77339.jpg (similarity: 0.5117)
#   → 25538f1cba0644bda85ff266859e22c7.jpg (similarity: 0.5037)
#
# Query: 930a21caf10540ec969ccf760054168b.jpg
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.7318)
#   → 35e8624e2c31435ca232d9c2ab6a963c.jpg (similarity: 0.6946)
#   → 5d510e7156844170b7cbc3ac98647819.jpg (similarity: 0.6818)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6761)
#   → efbd498f5c7545d7a67e6f76e98c54e4.jpg (similarity: 0.6505)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.6487)
#   → 98377d076a9d40af8229ea8d67c65f11.jpg (similarity: 0.6467)
#   → a75d79ce216f4c838eef372406848f14.jpg (similarity: 0.6322)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.6206)
#   → 0846c9fb262147adb410ddd029e4b646.jpg (similarity: 0.6176)
#
# Query: e196a4f93fc740cc8b2c3ba9e16db759.jpg
#   → a75d79ce216f4c838eef372406848f14.jpg (similarity: 0.7812)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.7649)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.7442)
#   → 9f2e65949b644b859d3383bac0028f86.jpg (similarity: 0.7343)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.7339)
#   → 1737f3015d3d4814bfe46aa6a6298a5e.jpg (similarity: 0.6870)
#   → 0a3195260ab54d7f83c5ebff96b8a934.jpg (similarity: 0.6556)
#   → 4f6a3f8c9e8346d3ba8ef74a4c48b056.jpg (similarity: 0.6505)
#   → 13c731f0d73d41e0b051ed8773b673d6.jpg (similarity: 0.6503)
#   → 3e16c04505d94bee99c53e80af01956f.jpg (similarity: 0.6475)
#
# Query: c4de8bc421254d54aee807f672f30cf6.jpg
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.5241)
#   → 2fdffe8cb2064babb807fba2fbbc4eab.jpg (similarity: 0.5217)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.5084)
#   → 07c664a8ee4c44d0bfb0b668f64b0ffb.jpg (similarity: 0.5062)
#   → bc6a7f60881a44dda07f0e091cf8d288.jpg (similarity: 0.4975)
#   → f8f7b32e84dc4615979fbda2d9cc6bfb.jpg (similarity: 0.4913)
#   → b2d4d854428d4ea6aa8761e077a77339.jpg (similarity: 0.4828)
#   → ef586363b8914ea18c4142ce2eef95fe.jpg (similarity: 0.4755)
#   → 9a5992cc77ad48dea095cfd93790cd34.jpg (similarity: 0.4741)
#   → 272e1e5125944ea9a8513074c3047c89.jpg (similarity: 0.4735)
#
# Query: a50a7486a93e498d947c6a5c355e46a0.jpg
#   → 82d4474b759344d1ad9961b9c79e325b.jpg (similarity: 0.7136)
#   → 255be13815844aca9393ec2fdc6861ab.jpg (similarity: 0.7104)
#   → bd585232e2084ba38091df4260bc096e.jpg (similarity: 0.7050)
#   → 5943480af7124c46b4353febb94b253e.jpg (similarity: 0.7019)
#   → de47340e9beb4a1b872709bb6d05e4ca.jpg (similarity: 0.6896)
#   → 92b60ca052904ed8b416b6f8f8b75216.jpg (similarity: 0.6894)
#   → 3fcf5cff2e2044b39b0521e2fb79ec9f.jpg (similarity: 0.6887)
#   → 6b15b995eed64b6b8a9258951bcb1969.jpg (similarity: 0.6836)
#   → b4f25adb5daa4ecda29fefdace1fbf7e.jpg (similarity: 0.6811)
#   → aa7e33db3b064e48a417ddce955237d3.jpg (similarity: 0.6761)
#
# Query: b15296868bb042e5b3596546efdf6564.jpg
#   → a912219187564c9fbadb37efebdf9eaa.jpg (similarity: 0.5508)
#   → 0416b7f2fcb34b19893444e50f88ba3b.jpg (similarity: 0.5265)
#   → 4a050c59736740599b570773a6e8c7e9.jpg (similarity: 0.5128)
#   → b81efa26a9e643028b5c3d8a0727e74b.jpg (similarity: 0.4960)
#   → 099334011ebd4351921d0b1228bc48e5.jpg (similarity: 0.4806)
#   → a29ab68f6cdc4ba68eca29ca82eb716e.jpg (similarity: 0.4672)
#   → 3d478ac9acd8497384385707add961c9.jpg (similarity: 0.4642)
#   → dcfc424adcb74dde95ac45dbf1937de4.jpg (similarity: 0.4629)
#   → 01625719f5ce4dc7b300088f61ee1bd1.jpg (similarity: 0.4592)
#   → 3e8fbbd943a84c698afc69b685961bce.jpg (similarity: 0.4590)
#
# Query: a1d9e212e25a4efa9eccb55ec8688e78.jpg
#   → a912219187564c9fbadb37efebdf9eaa.jpg (similarity: 0.6223)
#   → 01625719f5ce4dc7b300088f61ee1bd1.jpg (similarity: 0.5579)
#   → 63bb53a60409435fb90f48534232180e.jpg (similarity: 0.5431)
#   → 3fcf5cff2e2044b39b0521e2fb79ec9f.jpg (similarity: 0.5371)
#   → 479760aa0c1f48e8801f48e1ac95fdfe.jpg (similarity: 0.5303)
#   → 0416b7f2fcb34b19893444e50f88ba3b.jpg (similarity: 0.5285)
#   → 7e39906b7a0040119df355667929a4c0.jpg (similarity: 0.5224)
#   → a29ab68f6cdc4ba68eca29ca82eb716e.jpg (similarity: 0.5206)
#   → ddffdade273c4c04beffc8680574fef6.jpg (similarity: 0.5205)
#   → 4a050c59736740599b570773a6e8c7e9.jpg (similarity: 0.5197)
#
# Query: cb6a9503520548b0ba7b9d19b7ddfa60.jpg
#   → de47340e9beb4a1b872709bb6d05e4ca.jpg (similarity: 0.7858)
#   → 82d4474b759344d1ad9961b9c79e325b.jpg (similarity: 0.7807)
#   → 3fcf5cff2e2044b39b0521e2fb79ec9f.jpg (similarity: 0.7798)
#   → 0416b7f2fcb34b19893444e50f88ba3b.jpg (similarity: 0.7743)
#   → a29ab68f6cdc4ba68eca29ca82eb716e.jpg (similarity: 0.7424)
#   → e049f58a55f049afb1215cc38a146a94.jpg (similarity: 0.7252)
#   → f0c0b95cdac4476baf9eb270c582f7cf.jpg (similarity: 0.7033)
#   → 255be13815844aca9393ec2fdc6861ab.jpg (similarity: 0.6992)
#   → 099334011ebd4351921d0b1228bc48e5.jpg (similarity: 0.6980)
#   → a2ea23aa344c4134b1ae5b34e42aa9e4.jpg (similarity: 0.6916)
#
# Query: 4f997c0d879241378b96b4f0cdf543f4.jpg
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.7752)
#   → 35e8624e2c31435ca232d9c2ab6a963c.jpg (similarity: 0.7399)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.7349)
#   → 0a400d67f9c24c5cb871e67b95af2280.jpg (similarity: 0.7151)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.7010)
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.6999)
#   → 782192d4a9ea4ff48101b051810c14d1.jpg (similarity: 0.6921)
#   → 0846c9fb262147adb410ddd029e4b646.jpg (similarity: 0.6877)
#   → f8f7b32e84dc4615979fbda2d9cc6bfb.jpg (similarity: 0.6867)
#   → efbd498f5c7545d7a67e6f76e98c54e4.jpg (similarity: 0.6835)
#
# Query: 5fd5f93201f54a638755930b055f4824.jpg
#   → 77fd48716bea4185aa6f682fc152ef8e.jpg (similarity: 0.5096)
#   → bc6a7f60881a44dda07f0e091cf8d288.jpg (similarity: 0.4622)
#   → 6163132f142246fbba72675a751602c0.jpg (similarity: 0.4609)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.4508)
#   → 66fbba74d284497b868e42d65e0ea089.jpg (similarity: 0.4435)
#   → cd3f92386caa49fd8ed366de37d85a3f.jpg (similarity: 0.4403)
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.4381)
#   → 4e1c4a8c479547ab8628d0951955a6e9.jpg (similarity: 0.4352)
#   → 4f6a3f8c9e8346d3ba8ef74a4c48b056.jpg (similarity: 0.4277)
#   → 0a400d67f9c24c5cb871e67b95af2280.jpg (similarity: 0.4258)
#
# Query: 0c2de0b44617419a96fbe33558f81eca.jpg
#   → 6e1fd42f80474defb740ff40638a119f.jpg (similarity: 0.6246)
#   → 306150c25d8042daab0acba46dac6025.jpg (similarity: 0.6238)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.6233)
#   → 5f902dfcee33489787a93d0d47ff19b2.jpg (similarity: 0.6142)
#   → 153595449fb448b2882e8765d75a9fa6.jpg (similarity: 0.6095)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.6039)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.5971)
#   → f8f7b32e84dc4615979fbda2d9cc6bfb.jpg (similarity: 0.5929)
#   → 36d4bce2b813451db9c33958d77b4182.jpg (similarity: 0.5856)
#   → 73c30f0764d549b5b371929e364a0087.jpg (similarity: 0.5853)
#
# Query: 05597b036b0548db888da1032cd73f60.jpg
#   → 708d1afa4c3240f5873486a5f7489d5c.jpg (similarity: 0.6339)
#   → 576b62b9f236435cadfb2406edab09e3.jpg (similarity: 0.5973)
#   → 306150c25d8042daab0acba46dac6025.jpg (similarity: 0.5879)
#   → 73c30f0764d549b5b371929e364a0087.jpg (similarity: 0.5783)
#   → 4f6a3f8c9e8346d3ba8ef74a4c48b056.jpg (similarity: 0.5682)
#   → 3c38b9025f3145b896507fd3cf57217e.jpg (similarity: 0.5645)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.5553)
#   → 427749e1924b462faef16b55821fa715.jpg (similarity: 0.5450)
#   → 43ca0f3893594535b6bc19e9de3fd259.jpg (similarity: 0.5433)
#   → 9f2e65949b644b859d3383bac0028f86.jpg (similarity: 0.5401)
#
# Query: f56972390a6949c2a2b9dc8d1fcbd1b4.jpg
#   → a2ea23aa344c4134b1ae5b34e42aa9e4.jpg (similarity: 0.7173)
#   → ffe2ca5e835147c985a5b046e9053c26.jpg (similarity: 0.7148)
#   → 3e8fbbd943a84c698afc69b685961bce.jpg (similarity: 0.6660)
#   → 855b6983eb124fb688a8d4e025c02f3a.jpg (similarity: 0.6586)
#   → bd585232e2084ba38091df4260bc096e.jpg (similarity: 0.6581)
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.6449)
#   → 6c82a7a5d2654dbf8a63e2368be385b5.jpg (similarity: 0.6433)
#   → 6b15b995eed64b6b8a9258951bcb1969.jpg (similarity: 0.6329)
#   → 255be13815844aca9393ec2fdc6861ab.jpg (similarity: 0.6281)
#   → 974b76686b8b4687882f4ec7ae48904a.jpg (similarity: 0.6248)
#
# Query: 3158f68473ec4fcaac1971202decfcee.jpg
#   → 1737f3015d3d4814bfe46aa6a6298a5e.jpg (similarity: 0.6954)
#   → 9f2e65949b644b859d3383bac0028f86.jpg (similarity: 0.6844)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6796)
#   → 55987960e55541a983778be2751145e0.jpg (similarity: 0.6619)
#   → 0a3195260ab54d7f83c5ebff96b8a934.jpg (similarity: 0.6547)
#   → 4f6a3f8c9e8346d3ba8ef74a4c48b056.jpg (similarity: 0.6517)
#   → 43ca0f3893594535b6bc19e9de3fd259.jpg (similarity: 0.6321)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.6313)
#   → 708d1afa4c3240f5873486a5f7489d5c.jpg (similarity: 0.6290)
#   → 501fea8ef97940d0a569ad619189c40d.jpg (similarity: 0.6276)
#
# Query: 030a5f719e2940e9a8586447b4e4bd87.jpg
#   → 9a5992cc77ad48dea095cfd93790cd34.jpg (similarity: 0.6088)
#   → 0d1be9cdac5a4ff58a704b0d5e858008.jpg (similarity: 0.6004)
#   → 5249b4453c704cfc83c8186773674c98.jpg (similarity: 0.5965)
#   → 4d376e7797cd4796b5ffac4fed1cf609.jpg (similarity: 0.5955)
#   → 7a17c99d881f42e3b34e5e9e9005c611.jpg (similarity: 0.5905)
#   → 72ff0e3ce6c64326900397e25ff99de0.jpg (similarity: 0.5868)
#   → 36d4bce2b813451db9c33958d77b4182.jpg (similarity: 0.5786)
#   → 8a5de1abd9e24b3b855901bc5fd813a1.jpg (similarity: 0.5741)
#   → 10924d813ab14685aac4a50f1620be32.jpg (similarity: 0.5693)
#   → 101d860da2f44ca19b252d54e6390a5f.jpg (similarity: 0.5676)
#
# Query: 3e6e4e0b336c438fa545ea2e45ebf0a4.jpg
#   → c244787d0adf41f5b5cc255c3ba67652.jpg (similarity: 0.5568)
#   → d0926b126e744e71aba05609563290ac.jpg (similarity: 0.5411)
#   → 696bbc34686c43edb1b01d271b6cdd53.jpg (similarity: 0.5394)
#   → 7a3ac117a37a409b86c9417cf058ef3d.jpg (similarity: 0.5319)
#   → 87fdbb4d5eee49e19898ebc797130735.jpg (similarity: 0.5311)
#   → 0a1b8c413c3d4484a3451ce93ee97cd0.jpg (similarity: 0.5295)
#   → d9f3c18195d84bd58eac23ba635eea4c.jpg (similarity: 0.5280)
#   → 9c031e5004ea4550b7fde1b694cd059b.jpg (similarity: 0.5243)
#   → 16121b03302043e9adcd0d12ac5a057b.jpg (similarity: 0.5117)
#   → 3703656c904547729960a873139fc3ee.jpg (similarity: 0.5102)
#
# Query: 769c20e87c3444fdb4201a41be468392.jpg
#   → e67b699998a0446eab846b82dbd7a094.jpg (similarity: 0.6722)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.6602)
#   → 7b22cba2fbbe45e8ab131ea2f440f46b.jpg (similarity: 0.6441)
#   → bd585232e2084ba38091df4260bc096e.jpg (similarity: 0.6363)
#   → ef586363b8914ea18c4142ce2eef95fe.jpg (similarity: 0.6162)
#   → 747a83fa3bf74542a947fcf4ae547eb3.jpg (similarity: 0.6110)
#   → 50c31597bfd64561b7d6650d19300077.jpg (similarity: 0.6032)
#   → 4b0e25833ad64aca8705fc305c8b705b.jpg (similarity: 0.6030)
#   → 8eab808a1615432e8f51c3543db426cf.jpg (similarity: 0.5993)
#   → 0de168ac81444017b44338d9ae5f136b.jpg (similarity: 0.5963)
#
# Query: b642baa26d1b4c17bc13b28fa4b808d0.jpg
#   → 43ca0f3893594535b6bc19e9de3fd259.jpg (similarity: 0.6013)
#   → 306150c25d8042daab0acba46dac6025.jpg (similarity: 0.5940)
#   → 708d1afa4c3240f5873486a5f7489d5c.jpg (similarity: 0.5836)
#   → 92b275e4f08041879e5d278e54ef27f4.jpg (similarity: 0.5827)
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.5823)
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.5779)
#   → 94230205a3054ca49a216551ed6783b8.jpg (similarity: 0.5762)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.5755)
#   → d8b312bdfa864076a1a3b32586ff1d0e.jpg (similarity: 0.5730)
#   → e67b699998a0446eab846b82dbd7a094.jpg (similarity: 0.5715)
#
# Query: f23eab78d6544845b4ffbb285601252a.jpg
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.7529)
#   → a78290d8a23d4faeab2a993c95552e83.jpg (similarity: 0.6833)
#   → 272e1e5125944ea9a8513074c3047c89.jpg (similarity: 0.6630)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.6518)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.6312)
#   → f8f7b32e84dc4615979fbda2d9cc6bfb.jpg (similarity: 0.6297)
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.6294)
#   → 50a45e63e946442fa3a0b6efc8a5a73a.jpg (similarity: 0.6268)
#   → e67b699998a0446eab846b82dbd7a094.jpg (similarity: 0.6227)
#   → a654dcca4bc54a7982196a9a85fe4f51.jpg (similarity: 0.6214)
#
# Query: bccc9b9c8832416bbfe8e95365110ad0.jpg
#   → b2d4d854428d4ea6aa8761e077a77339.jpg (similarity: 0.6192)
#   → 297a17348d83486987e946130e6b53de.jpg (similarity: 0.5967)
#   → 9a5992cc77ad48dea095cfd93790cd34.jpg (similarity: 0.5921)
#   → ef586363b8914ea18c4142ce2eef95fe.jpg (similarity: 0.5886)
#   → f8f7b32e84dc4615979fbda2d9cc6bfb.jpg (similarity: 0.5878)
#   → 5f902dfcee33489787a93d0d47ff19b2.jpg (similarity: 0.5839)
#   → 94dba9d9b3a44a448af2e45dd43c27f4.jpg (similarity: 0.5569)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.5507)
#   → 81dcca6e51694385b9eb96aac08fc690.jpg (similarity: 0.5488)
#   → c010ab8acc8a447685cd9c279ebd693c.jpg (similarity: 0.5485)
#
# Query: ac273c81e7f24fce81cf002002eebb98.jpg
#   → 35e8624e2c31435ca232d9c2ab6a963c.jpg (similarity: 0.6005)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.5864)
#   → 98377d076a9d40af8229ea8d67c65f11.jpg (similarity: 0.5792)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.5739)
#   → 0aa5fb8861264af397ab6692a2b23122.jpg (similarity: 0.5615)
#   → a75d79ce216f4c838eef372406848f14.jpg (similarity: 0.5464)
#   → 3aa120cc76c444c0bf01b5c0932b864c.jpg (similarity: 0.5433)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.5407)
#   → 55987960e55541a983778be2751145e0.jpg (similarity: 0.5368)
#   → 153595449fb448b2882e8765d75a9fa6.jpg (similarity: 0.5360)
#
# Query: a7afb62dfbba4aca8145ed44867740cb.jpg
#   → a2ea23aa344c4134b1ae5b34e42aa9e4.jpg (similarity: 0.6520)
#   → 3e8fbbd943a84c698afc69b685961bce.jpg (similarity: 0.6414)
#   → a5bad5611d0648ebb5518fc7ae0dcab5.jpg (similarity: 0.6122)
#   → b2d4787d79dd453a9a331d1bf2b46dab.jpg (similarity: 0.6095)
#   → bf02c73f35cf44e89c2f34b82bc3d09e.jpg (similarity: 0.6068)
#   → 10924d813ab14685aac4a50f1620be32.jpg (similarity: 0.5845)
#   → 19116503957b47f7b419e38f1ea93b6f.jpg (similarity: 0.5832)
#   → 3dd1c34588b2415bb74024a8b9b35d77.jpg (similarity: 0.5789)
#   → 8a5de1abd9e24b3b855901bc5fd813a1.jpg (similarity: 0.5775)
#   → 87329be931b14ca7aef0950b8835f92f.jpg (similarity: 0.5750)
#
# Query: d13126cde2fd49fe9bd2ba83cf6d81e4.jpg
#   → 70129aa7188a43be83559eead099832b.jpg (similarity: 0.5652)
#   → e2be29c99f724012b61590af470e8156.jpg (similarity: 0.4677)
#   → f01250f7f83840dcaa36833cceb0a321.jpg (similarity: 0.4622)
#   → 326e4e826f584c42b4edfe7fa321cb88.jpg (similarity: 0.4582)
#   → 53eb32f3e6a54ef3931367e64e2f3258.jpg (similarity: 0.4507)
#   → a1cc8ed763064cc79e53634d16a4c3d9.jpg (similarity: 0.4505)
#   → 64c047c043ff45d2b9cc035e79d8630e.jpg (similarity: 0.4401)
#   → ef92849d2a394c2ca1719aa2f3e8dc4c.jpg (similarity: 0.4375)
#   → a48e3eeece384de194d82df1cc78b414.jpg (similarity: 0.4346)
#   → b2f68e6d2bcc4a91b98a7c25057a4325.jpg (similarity: 0.4334)
#
# Query: e3c6ae92533a47d292ac393b5917f580.jpg
#   → 365066184b83492fabaa9acc5ca243ab.jpg (similarity: 0.7388)
#   → 7c3f3cae7dbd481191f246c6502b8607.jpg (similarity: 0.7035)
#   → 908760751db8473c84174654952e5c56.jpg (similarity: 0.6943)
#   → e41584849e7246b0b893deceab68eb97.jpg (similarity: 0.6775)
#   → 3e16c04505d94bee99c53e80af01956f.jpg (similarity: 0.6771)
#   → 15c94aaa148142b28ab57712e6377450.jpg (similarity: 0.6745)
#   → d8b312bdfa864076a1a3b32586ff1d0e.jpg (similarity: 0.6711)
#   → 449c60df60bd43e188e534b283661303.jpg (similarity: 0.6705)
#   → 4f6a3f8c9e8346d3ba8ef74a4c48b056.jpg (similarity: 0.6682)
#   → 4f756125c3a845f1af9e02a02e2b3843.jpg (similarity: 0.6487)
#
# Query: 578d2a6c99ad409eb0b55e027ae9310c.jpg
#   → 9f2e65949b644b859d3383bac0028f86.jpg (similarity: 0.6540)
#   → a75d79ce216f4c838eef372406848f14.jpg (similarity: 0.6464)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6134)
#   → 1737f3015d3d4814bfe46aa6a6298a5e.jpg (similarity: 0.6128)
#   → 4f6a3f8c9e8346d3ba8ef74a4c48b056.jpg (similarity: 0.5945)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.5931)
#   → 55987960e55541a983778be2751145e0.jpg (similarity: 0.5920)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.5829)
#   → 501fea8ef97940d0a569ad619189c40d.jpg (similarity: 0.5676)
#   → 0a3195260ab54d7f83c5ebff96b8a934.jpg (similarity: 0.5590)
#
# Query: a5090876a25c4d288f4cd6708ca04ab1.jpg
#   → f8f7b32e84dc4615979fbda2d9cc6bfb.jpg (similarity: 0.5996)
#   → b2d4d854428d4ea6aa8761e077a77339.jpg (similarity: 0.5731)
#   → 81dcca6e51694385b9eb96aac08fc690.jpg (similarity: 0.5393)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.5388)
#   → 297a17348d83486987e946130e6b53de.jpg (similarity: 0.5335)
#   → 9a5992cc77ad48dea095cfd93790cd34.jpg (similarity: 0.5219)
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.5190)
#   → 5d201a49f13f4f81ac99d2b95dee08de.jpg (similarity: 0.5135)
#   → 4d376e7797cd4796b5ffac4fed1cf609.jpg (similarity: 0.5130)
#   → 5fc8a73b015141b29527c922ce3fcdaa.jpg (similarity: 0.5076)
#
# Query: 6f6af23e036d4f7da6c977d949b26a2d.jpg
#   → 38f009d970c042268aa7d93cfeaf6638.jpg (similarity: 0.5144)
#   → 5249b4453c704cfc83c8186773674c98.jpg (similarity: 0.5051)
#   → 566cf7e9bfc941409e2c7121ee252bb8.jpg (similarity: 0.5045)
#   → 255be13815844aca9393ec2fdc6861ab.jpg (similarity: 0.5030)
#   → 9a5992cc77ad48dea095cfd93790cd34.jpg (similarity: 0.5018)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.5010)
#   → 0d1be9cdac5a4ff58a704b0d5e858008.jpg (similarity: 0.4998)
#   → ef586363b8914ea18c4142ce2eef95fe.jpg (similarity: 0.4987)
#   → 3e8fbbd943a84c698afc69b685961bce.jpg (similarity: 0.4963)
#   → 14011651632943ecaeac7f637c0c9ef1.jpg (similarity: 0.4955)
#
# Query: 7fa9740994a94fcfb7372ca76df4669f.jpg
#   → c9ac695880fa4582bb0fec1543e40bfd.jpg (similarity: 0.5744)
#   → d306e139a05c4b17bca41fae41c6eb56.jpg (similarity: 0.4718)
#   → 4d376e7797cd4796b5ffac4fed1cf609.jpg (similarity: 0.4703)
#   → 15c94aaa148142b28ab57712e6377450.jpg (similarity: 0.4528)
#   → 2c0a67531f2d4712a51186abeeff5533.jpg (similarity: 0.4446)
#   → 33d6d48024e24657b667d5ec7827a836.jpg (similarity: 0.4376)
#   → c4b9aaef4a5945db91777569622d155c.jpg (similarity: 0.4298)
#   → 2523763d11154f0380acc67e8a7fd651.jpg (similarity: 0.4118)
#   → 24686a3c253849a29cbf64bc4da7c7f7.jpg (similarity: 0.4082)
#   → a6d09bee1d414a489b9d53a287fa4966.jpg (similarity: 0.4044)
#
# Query: 4bd5fd308a7b4f3caf369a398c6ae76d.jpg
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.6818)
#   → b2d4d854428d4ea6aa8761e077a77339.jpg (similarity: 0.6762)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.6611)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.6557)
#   → 1737f3015d3d4814bfe46aa6a6298a5e.jpg (similarity: 0.6512)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.6493)
#   → c8601b2a626143e3b30442901831c268.jpg (similarity: 0.6452)
#   → 974b76686b8b4687882f4ec7ae48904a.jpg (similarity: 0.6431)
#   → 50a45e63e946442fa3a0b6efc8a5a73a.jpg (similarity: 0.6420)
#   → e67b699998a0446eab846b82dbd7a094.jpg (similarity: 0.6348)
#
# Query: af788faf078b473484d4177c310506cb.jpg
#   → 449c60df60bd43e188e534b283661303.jpg (similarity: 0.7335)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6802)
#   → 9f2e65949b644b859d3383bac0028f86.jpg (similarity: 0.6609)
#   → 272e1e5125944ea9a8513074c3047c89.jpg (similarity: 0.6493)
#   → 50a45e63e946442fa3a0b6efc8a5a73a.jpg (similarity: 0.6466)
#   → 0a3195260ab54d7f83c5ebff96b8a934.jpg (similarity: 0.6329)
#   → 2794862196ed463fb5b2a6bde29be065.jpg (similarity: 0.6325)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.6314)
#   → 1737f3015d3d4814bfe46aa6a6298a5e.jpg (similarity: 0.6199)
#   → 43ca0f3893594535b6bc19e9de3fd259.jpg (similarity: 0.6113)
#
# Query: 223c8d2de8c24164a36a934c4889da0e.jpg
#   → a912219187564c9fbadb37efebdf9eaa.jpg (similarity: 0.6530)
#   → b81efa26a9e643028b5c3d8a0727e74b.jpg (similarity: 0.5756)
#   → 7b22cba2fbbe45e8ab131ea2f440f46b.jpg (similarity: 0.5549)
#   → 4b115fb236594790b891e5ef0fcc0fca.jpg (similarity: 0.5467)
#   → 63048628a95642ba833edea02df177b6.jpg (similarity: 0.5404)
#   → 3e8fbbd943a84c698afc69b685961bce.jpg (similarity: 0.5364)
#   → a29ab68f6cdc4ba68eca29ca82eb716e.jpg (similarity: 0.5277)
#   → 7e39906b7a0040119df355667929a4c0.jpg (similarity: 0.5276)
#   → 92b60ca052904ed8b416b6f8f8b75216.jpg (similarity: 0.5216)
#   → 01625719f5ce4dc7b300088f61ee1bd1.jpg (similarity: 0.5128)
#
# Query: 78cfa4ce9c174b68bfa63b2175e9f252.jpg
#   → 6f0f677b905243e7a0b2195e3774f56e.jpg (similarity: 0.6812)
#   → 297a17348d83486987e946130e6b53de.jpg (similarity: 0.6751)
#   → c176fa2940224efc9e3a657d09cb6dbc.jpg (similarity: 0.6629)
#   → 514c141d16e44dee81b34bb9d2683fe0.jpg (similarity: 0.6605)
#   → fea9380f974848d9a2571556a666e8a5.jpg (similarity: 0.6520)
#   → ad4c283fc3204ede88de7baf92aa45e8.jpg (similarity: 0.6438)
#   → 4791018f6460435ab06d7c5a4e168279.jpg (similarity: 0.6413)
#   → 0256fcdbedd64493a0430464c9dd9b57.jpg (similarity: 0.6383)
#   → bc22cee99d1147b8ba305792a1e902db.jpg (similarity: 0.6335)
#   → 16121b03302043e9adcd0d12ac5a057b.jpg (similarity: 0.6308)
#
# Query: a561c17228ea40bc8d38aafc18d77006.jpg
#   → 87329be931b14ca7aef0950b8835f92f.jpg (similarity: 0.6616)
#   → 3af1d6acbab44703b24d804457d3ca25.jpg (similarity: 0.6519)
#   → 0d1be9cdac5a4ff58a704b0d5e858008.jpg (similarity: 0.6505)
#   → ad9fa1f6167a4972b3fe232f361b1ff3.jpg (similarity: 0.6438)
#   → 589ba1a3e6ac4f75a298efe8758e8975.jpg (similarity: 0.6378)
#   → 53b419b18f444399adf3f35f4f1eca54.jpg (similarity: 0.6327)
#   → 4524454d3cb9401eb4e155e42143bc73.jpg (similarity: 0.6323)
#   → 3c138f4655a244ea886f0a7feca0f2e0.jpg (similarity: 0.6298)
#   → c13d64eb2dea4697a1710696eb5d2748.jpg (similarity: 0.6230)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.6225)
#
# Query: 34c78b19453e453cb45236fae1a0b1f2.jpg
#   → 38d9530af58d4c11ae8334aad91b3a35.jpg (similarity: 0.5321)
#   → 625c897089ce479896e6b29b4c56b3b3.jpg (similarity: 0.5094)
#   → 10924d813ab14685aac4a50f1620be32.jpg (similarity: 0.4410)
#   → 0de168ac81444017b44338d9ae5f136b.jpg (similarity: 0.4300)
#   → 72c5ee0e391345f7b1fe2b2a4a63fac6.jpg (similarity: 0.4291)
#   → 855b6983eb124fb688a8d4e025c02f3a.jpg (similarity: 0.4162)
#   → d54a5f3614ff477da2b21fc9a1f7f646.jpg (similarity: 0.4131)
#   → 64e6110ca263483d81c8a3f3abfff11c.jpg (similarity: 0.4057)
#   → 1f3eb675f4574972b40141ed003020cc.jpg (similarity: 0.3921)
#   → 79734fab647a43aba11170b58533f14a.jpg (similarity: 0.3907)
#
# Query: 1fdcb68d4682436da0d07c6f0d06f1b9.jpg
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.6286)
#   → a78290d8a23d4faeab2a993c95552e83.jpg (similarity: 0.6268)
#   → 449c60df60bd43e188e534b283661303.jpg (similarity: 0.6141)
#   → 50a45e63e946442fa3a0b6efc8a5a73a.jpg (similarity: 0.6045)
#   → 272e1e5125944ea9a8513074c3047c89.jpg (similarity: 0.5942)
#   → d18ed82025c94a6291b357b538e341d2.jpg (similarity: 0.5892)
#   → 4d376e7797cd4796b5ffac4fed1cf609.jpg (similarity: 0.5867)
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.5844)
#   → 15c94aaa148142b28ab57712e6377450.jpg (similarity: 0.5794)
#   → b2d4d854428d4ea6aa8761e077a77339.jpg (similarity: 0.5751)
#
# Query: 8c770a2468d546259771c9f6c951e379.jpg
#   → e67b699998a0446eab846b82dbd7a094.jpg (similarity: 0.6132)
#   → 2883c9301c424c8ba0db796acabd0837.jpg (similarity: 0.5932)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.5721)
#   → 50c31597bfd64561b7d6650d19300077.jpg (similarity: 0.5640)
#   → cbf28ae2f7ae4aafb9938315e5c072fd.jpg (similarity: 0.5632)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.5580)
#   → 1737f3015d3d4814bfe46aa6a6298a5e.jpg (similarity: 0.5580)
#   → 0a1b8c413c3d4484a3451ce93ee97cd0.jpg (similarity: 0.5416)
#   → 0187787fd15a4cb5a7e7e227160c3bec.jpg (similarity: 0.5391)
#   → 049b584b3af9408493b432cfd9cba577.jpg (similarity: 0.5374)
#
# Query: d574ecd74d684dbfb3f864dd7494e4cc.jpg
#   → 55987960e55541a983778be2751145e0.jpg (similarity: 0.6307)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.6154)
#   → 13c731f0d73d41e0b051ed8773b673d6.jpg (similarity: 0.6144)
#   → 4f6a3f8c9e8346d3ba8ef74a4c48b056.jpg (similarity: 0.6101)
#   → 501fea8ef97940d0a569ad619189c40d.jpg (similarity: 0.6067)
#   → 6874eb937a564f068fb8072cc4470d0b.jpg (similarity: 0.5838)
#   → 50a45e63e946442fa3a0b6efc8a5a73a.jpg (similarity: 0.5780)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.5740)
#   → 43ca0f3893594535b6bc19e9de3fd259.jpg (similarity: 0.5710)
#   → 9f2e65949b644b859d3383bac0028f86.jpg (similarity: 0.5708)
#
# Query: 0fd61d8033ed439fb28492351aede35e.jpg
#   → 19116503957b47f7b419e38f1ea93b6f.jpg (similarity: 0.5792)
#   → b02514edcc0845e0a3cc528c56809e92.jpg (similarity: 0.5791)
#   → 5fe55b528d8f4df480d33e04163bef2a.jpg (similarity: 0.5732)
#   → dcd0e190676043c4900ad97afbde007c.jpg (similarity: 0.5689)
#   → 98d2b5135ea54c89a7c5ec9f0698227e.jpg (similarity: 0.5638)
#   → 2b47c9441a6541389da433e9f7182ae0.jpg (similarity: 0.5621)
#   → 92434ad06d3d4fad8a1cf6c52ae3685c.jpg (similarity: 0.5595)
#   → 322fbafc147b4180b10b5af72fa4e353.jpg (similarity: 0.5589)
#   → 2fdffe8cb2064babb807fba2fbbc4eab.jpg (similarity: 0.5579)
#   → 1e537a3e2eb74086a6ca10863f74f7f2.jpg (similarity: 0.5556)
#
# Query: e6e2c9920f734d0bb0212052bf73ddff.jpg
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.7747)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.7416)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6998)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.6902)
#   → 1737f3015d3d4814bfe46aa6a6298a5e.jpg (similarity: 0.6885)
#   → 35e8624e2c31435ca232d9c2ab6a963c.jpg (similarity: 0.6809)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.6759)
#   → 8b11436b42864cfcaba961db4e6dfcd9.jpg (similarity: 0.6593)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.6430)
#   → 9f2e65949b644b859d3383bac0028f86.jpg (similarity: 0.6417)
#
# Query: ce0a1ef20ab84168a904d2aae9de6fdb.jpg
#   → a5bad5611d0648ebb5518fc7ae0dcab5.jpg (similarity: 0.7214)
#   → 73a2379de5734bfd8243677a9e96cf57.jpg (similarity: 0.6865)
#   → 4c0eb389ea8a47dd8cb80556e926192b.jpg (similarity: 0.6858)
#   → 10924d813ab14685aac4a50f1620be32.jpg (similarity: 0.6851)
#   → b2d4787d79dd453a9a331d1bf2b46dab.jpg (similarity: 0.6782)
#   → 322fbafc147b4180b10b5af72fa4e353.jpg (similarity: 0.6476)
#   → 297a17348d83486987e946130e6b53de.jpg (similarity: 0.6468)
#   → 3d4c7881ca7a49d4be8f0f67b5efe394.jpg (similarity: 0.6432)
#   → c40e3185d3764318a5b1fbf15a462b43.jpg (similarity: 0.6421)
#   → 3d478ac9acd8497384385707add961c9.jpg (similarity: 0.6394)
#
# Query: d3d06c5c9a44432a993f790061d8fcbe.jpg
#   → ba4a48eeab94476693cc02231102ba04.jpg (similarity: 0.6466)
#   → 0a1b8c413c3d4484a3451ce93ee97cd0.jpg (similarity: 0.6338)
#   → c244787d0adf41f5b5cc255c3ba67652.jpg (similarity: 0.6319)
#   → 10924d813ab14685aac4a50f1620be32.jpg (similarity: 0.6291)
#   → 1465aa99754d4c8cae68e2d70ac2fe87.jpg (similarity: 0.6291)
#   → c13d64eb2dea4697a1710696eb5d2748.jpg (similarity: 0.6256)
#   → 7be0c095447e49d2b65009b94eac683f.jpg (similarity: 0.6190)
#   → cc74780f276f423aa446e8ee778aa192.jpg (similarity: 0.6182)
#   → 4524454d3cb9401eb4e155e42143bc73.jpg (similarity: 0.6166)
#   → 87329be931b14ca7aef0950b8835f92f.jpg (similarity: 0.6160)
#
# Query: c1af8b7735ad447d995f3c4a916588b3.jpg
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.7830)
#   → 3e16c04505d94bee99c53e80af01956f.jpg (similarity: 0.7703)
#   → 7c3f3cae7dbd481191f246c6502b8607.jpg (similarity: 0.7657)
#   → cf30b7a517b0436e82b4a99330cc0d93.jpg (similarity: 0.7587)
#   → 20881ddf8b7942ff996a75eacc8e1a70.jpg (similarity: 0.7203)
#   → 908760751db8473c84174654952e5c56.jpg (similarity: 0.7158)
#   → 365066184b83492fabaa9acc5ca243ab.jpg (similarity: 0.7153)
#   → d8b312bdfa864076a1a3b32586ff1d0e.jpg (similarity: 0.7116)
#   → 543f59153f0b493eb87f013534921bb5.jpg (similarity: 0.7095)
#   → d17206151e7c453fbe16f9fa816c679d.jpg (similarity: 0.7068)
#
# Query: e19eecc4416f4440baa3f3a7534c2e30.jpg
#   → 099334011ebd4351921d0b1228bc48e5.jpg (similarity: 0.6887)
#   → 3e8fbbd943a84c698afc69b685961bce.jpg (similarity: 0.6307)
#   → b81efa26a9e643028b5c3d8a0727e74b.jpg (similarity: 0.6199)
#   → a29ab68f6cdc4ba68eca29ca82eb716e.jpg (similarity: 0.6157)
#   → 4b115fb236594790b891e5ef0fcc0fca.jpg (similarity: 0.6145)
#   → a912219187564c9fbadb37efebdf9eaa.jpg (similarity: 0.6106)
#   → bf02c73f35cf44e89c2f34b82bc3d09e.jpg (similarity: 0.6074)
#   → 01625719f5ce4dc7b300088f61ee1bd1.jpg (similarity: 0.6010)
#   → 2fe46e9cfada469198d20bb406ae5d2c.jpg (similarity: 0.6001)
#   → a2ea23aa344c4134b1ae5b34e42aa9e4.jpg (similarity: 0.5902)
#
# Query: 558913111bca448b8a9de969425bfce7.jpg
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.7839)
#   → 1737f3015d3d4814bfe46aa6a6298a5e.jpg (similarity: 0.7387)
#   → 9f2e65949b644b859d3383bac0028f86.jpg (similarity: 0.7307)
#   → 35e8624e2c31435ca232d9c2ab6a963c.jpg (similarity: 0.7282)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.7223)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.7171)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.7149)
#   → 0a3195260ab54d7f83c5ebff96b8a934.jpg (similarity: 0.6959)
#   → a75d79ce216f4c838eef372406848f14.jpg (similarity: 0.6922)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6782)
#
# Query: 3615f816fbc5425cab2a105d0c135739.jpg
#   → 50a45e63e946442fa3a0b6efc8a5a73a.jpg (similarity: 0.5868)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.5776)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.5660)
#   → 1547328594ce4bc9b2f4842a69e03292.jpg (similarity: 0.5655)
#   → 43ca0f3893594535b6bc19e9de3fd259.jpg (similarity: 0.5616)
#   → 1737f3015d3d4814bfe46aa6a6298a5e.jpg (similarity: 0.5488)
#   → 20881ddf8b7942ff996a75eacc8e1a70.jpg (similarity: 0.5406)
#   → 3e16c04505d94bee99c53e80af01956f.jpg (similarity: 0.5404)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.5398)
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.5388)
#
# Query: d6f98b1331504f7d8566f2615ce781a0.jpg
#   → f8a0089530524eff94f8cb050fa09444.jpg (similarity: 0.5543)
#   → 543f59153f0b493eb87f013534921bb5.jpg (similarity: 0.5468)
#   → 6d5324c104ab437ab6dfd0249359287b.jpg (similarity: 0.5130)
#   → 7c5b54387c61440482b9b7a4daee1691.jpg (similarity: 0.5015)
#   → 974b76686b8b4687882f4ec7ae48904a.jpg (similarity: 0.4996)
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.4953)
#   → 2794862196ed463fb5b2a6bde29be065.jpg (similarity: 0.4854)
#   → e97652e3b9ce4745ab96eb0a49f4bd30.jpg (similarity: 0.4791)
#   → 4e1c4a8c479547ab8628d0951955a6e9.jpg (similarity: 0.4716)
#   → cae307df22c04e59839ad3764a20d6bd.jpg (similarity: 0.4673)
#
# Query: f41a3e328e88424cb1e96e2bbadb82d3.jpg
#   → 41c718023eeb42a6b11370c19c44f7e8.jpg (similarity: 0.5556)
#   → c4b9aaef4a5945db91777569622d155c.jpg (similarity: 0.5132)
#   → 9c031e5004ea4550b7fde1b694cd059b.jpg (similarity: 0.5091)
#   → ecb9847d34c14a7f9e24b86ad5783325.jpg (similarity: 0.5090)
#   → 8eaf541cd9674f70a09fac712ba90843.jpg (similarity: 0.5036)
#   → a685da06f69e4f5d9bba7ccd9dd8f5b5.jpg (similarity: 0.4967)
#   → efb24f7df3f3475db395ef22f0c1e505.jpg (similarity: 0.4918)
#   → 5c93a2c93322448293fe141207736cda.jpg (similarity: 0.4886)
#   → 14a2384533574cbb96af580332ef71b3.jpg (similarity: 0.4856)
#   → acffb8e7c3fe4768a7cf2181b354aa99.jpg (similarity: 0.4823)
#
# Query: 873b7a8c8d6c4389a8acfc9ef3577c47.jpg
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.7917)
#   → 9f2e65949b644b859d3383bac0028f86.jpg (similarity: 0.7896)
#   → 501fea8ef97940d0a569ad619189c40d.jpg (similarity: 0.7508)
#   → 0a3195260ab54d7f83c5ebff96b8a934.jpg (similarity: 0.7471)
#   → 4f6a3f8c9e8346d3ba8ef74a4c48b056.jpg (similarity: 0.7443)
#   → 1737f3015d3d4814bfe46aa6a6298a5e.jpg (similarity: 0.7384)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.7323)
#   → 13c731f0d73d41e0b051ed8773b673d6.jpg (similarity: 0.7148)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.6986)
#   → 55987960e55541a983778be2751145e0.jpg (similarity: 0.6874)
#
# Query: be198f06c0aa431f93d4e242fcd0412d.jpg
#   → 4f6a3f8c9e8346d3ba8ef74a4c48b056.jpg (similarity: 0.6785)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6725)
#   → 0a3195260ab54d7f83c5ebff96b8a934.jpg (similarity: 0.6427)
#   → 449c60df60bd43e188e534b283661303.jpg (similarity: 0.6251)
#   → 708d1afa4c3240f5873486a5f7489d5c.jpg (similarity: 0.6054)
#   → 501fea8ef97940d0a569ad619189c40d.jpg (similarity: 0.6003)
#   → 272e1e5125944ea9a8513074c3047c89.jpg (similarity: 0.5953)
#   → 9f2e65949b644b859d3383bac0028f86.jpg (similarity: 0.5952)
#   → 13c731f0d73d41e0b051ed8773b673d6.jpg (similarity: 0.5910)
#   → 049b584b3af9408493b432cfd9cba577.jpg (similarity: 0.5837)
#
# Query: ec414930a18e46e094a46bc583ed2de3.jpg
#   → a5bad5611d0648ebb5518fc7ae0dcab5.jpg (similarity: 0.7094)
#   → 73a2379de5734bfd8243677a9e96cf57.jpg (similarity: 0.7075)
#   → 82d4474b759344d1ad9961b9c79e325b.jpg (similarity: 0.6962)
#   → a29ab68f6cdc4ba68eca29ca82eb716e.jpg (similarity: 0.6832)
#   → f0c0b95cdac4476baf9eb270c582f7cf.jpg (similarity: 0.6826)
#   → f53cf3f6ae5e46b9be619b0cd4151cd7.jpg (similarity: 0.6815)
#   → c834fcdf7e0d4810a61390a7cc956e95.jpg (similarity: 0.6786)
#   → 6b3292c7b15e4cbe9fd5eede2bc32521.jpg (similarity: 0.6750)
#   → 3d478ac9acd8497384385707add961c9.jpg (similarity: 0.6704)
#   → 5249b4453c704cfc83c8186773674c98.jpg (similarity: 0.6662)
#
# Query: 2461951317804aafb5210d254f1a8085.jpg
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.7386)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.7191)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.7062)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6979)
#   → f8f7b32e84dc4615979fbda2d9cc6bfb.jpg (similarity: 0.6880)
#   → 35e8624e2c31435ca232d9c2ab6a963c.jpg (similarity: 0.6752)
#   → 306150c25d8042daab0acba46dac6025.jpg (similarity: 0.6596)
#   → efbd498f5c7545d7a67e6f76e98c54e4.jpg (similarity: 0.6531)
#   → 5f902dfcee33489787a93d0d47ff19b2.jpg (similarity: 0.6530)
#   → 6e1fd42f80474defb740ff40638a119f.jpg (similarity: 0.6526)
#
# Query: b879d5d418b1480dafae0e4b8cefddc1.jpg
#   → 3fcf5cff2e2044b39b0521e2fb79ec9f.jpg (similarity: 0.7729)
#   → ddffdade273c4c04beffc8680574fef6.jpg (similarity: 0.7559)
#   → 82d4474b759344d1ad9961b9c79e325b.jpg (similarity: 0.7518)
#   → 7b22cba2fbbe45e8ab131ea2f440f46b.jpg (similarity: 0.7379)
#   → 099334011ebd4351921d0b1228bc48e5.jpg (similarity: 0.7273)
#   → 0416b7f2fcb34b19893444e50f88ba3b.jpg (similarity: 0.7220)
#   → 4a050c59736740599b570773a6e8c7e9.jpg (similarity: 0.7182)
#   → a29ab68f6cdc4ba68eca29ca82eb716e.jpg (similarity: 0.7175)
#   → 39159d7a30534f79a22e45c14db529e6.jpg (similarity: 0.7171)
#   → a912219187564c9fbadb37efebdf9eaa.jpg (similarity: 0.7131)
#
# Query: 701190ba7abf4ca7a39292b652987258.jpg
#   → 63bb53a60409435fb90f48534232180e.jpg (similarity: 0.6563)
#   → 82d4474b759344d1ad9961b9c79e325b.jpg (similarity: 0.6520)
#   → d74285f0a6dc4ce59bd43fbd81e42c01.jpg (similarity: 0.6461)
#   → 0416b7f2fcb34b19893444e50f88ba3b.jpg (similarity: 0.6352)
#   → 3fcf5cff2e2044b39b0521e2fb79ec9f.jpg (similarity: 0.6320)
#   → 01625719f5ce4dc7b300088f61ee1bd1.jpg (similarity: 0.6201)
#   → 7270e4db9490453e986b5a66aa5dc92b.jpg (similarity: 0.6095)
#   → 6528750542e843e7ad490a7ba0974df6.jpg (similarity: 0.6082)
#   → 140ea1752da94ff69f55357c2a58cf95.jpg (similarity: 0.6040)
#   → f0c0b95cdac4476baf9eb270c582f7cf.jpg (similarity: 0.6020)
#
# Query: 3f841cd6289d4b63b905c01d5ce82e6a.jpg
#   → 099334011ebd4351921d0b1228bc48e5.jpg (similarity: 0.6784)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.6777)
#   → de47340e9beb4a1b872709bb6d05e4ca.jpg (similarity: 0.6757)
#   → 3e8fbbd943a84c698afc69b685961bce.jpg (similarity: 0.6727)
#   → 7b22cba2fbbe45e8ab131ea2f440f46b.jpg (similarity: 0.6723)
#   → bf02c73f35cf44e89c2f34b82bc3d09e.jpg (similarity: 0.6650)
#   → d8dd9d9f3bdf411fa9a66d4f98f35a07.jpg (similarity: 0.6640)
#   → a2ea23aa344c4134b1ae5b34e42aa9e4.jpg (similarity: 0.6556)
#   → a29ab68f6cdc4ba68eca29ca82eb716e.jpg (similarity: 0.6554)
#   → 39159d7a30534f79a22e45c14db529e6.jpg (similarity: 0.6524)
#
# Query: 3e2d9a8a4b03468abc66eb421da5db8c.jpg
#   → 0a400d67f9c24c5cb871e67b95af2280.jpg (similarity: 0.7003)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.6934)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.6883)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6742)
#   → 272e1e5125944ea9a8513074c3047c89.jpg (similarity: 0.6604)
#   → 6e1fd42f80474defb740ff40638a119f.jpg (similarity: 0.6533)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6497)
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.6490)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.6470)
#   → f8f7b32e84dc4615979fbda2d9cc6bfb.jpg (similarity: 0.6454)
#
# Query: 35a41762c4e44931ac25bd92b7ec4e48.jpg
#   → 7b22cba2fbbe45e8ab131ea2f440f46b.jpg (similarity: 0.6727)
#   → b81efa26a9e643028b5c3d8a0727e74b.jpg (similarity: 0.6589)
#   → 4b115fb236594790b891e5ef0fcc0fca.jpg (similarity: 0.6572)
#   → a912219187564c9fbadb37efebdf9eaa.jpg (similarity: 0.6566)
#   → 099334011ebd4351921d0b1228bc48e5.jpg (similarity: 0.6540)
#   → 0416b7f2fcb34b19893444e50f88ba3b.jpg (similarity: 0.6475)
#   → dcca6280a42b4671a0b24b029cf67ce2.jpg (similarity: 0.6440)
#   → 7e39906b7a0040119df355667929a4c0.jpg (similarity: 0.6392)
#   → ddffdade273c4c04beffc8680574fef6.jpg (similarity: 0.6351)
#   → 4a050c59736740599b570773a6e8c7e9.jpg (similarity: 0.6277)
#
# Query: 5c942b70dd62476d8593a04c0a4ce465.jpg
#   → 86f8e4c129d94d27ad95b7d6659e5279.jpg (similarity: 0.6690)
#   → 40d031db85ca49deab4e3365f1419e6f.jpg (similarity: 0.6568)
#   → 76846611222b4a99a5d7faeb7575e390.jpg (similarity: 0.6498)
#   → 408363d42cf04a709a7b7e07e93eedd7.jpg (similarity: 0.6454)
#   → ad4c283fc3204ede88de7baf92aa45e8.jpg (similarity: 0.6425)
#   → 53948387e8aa4cab86f874d65f5246fd.jpg (similarity: 0.6413)
#   → 514c141d16e44dee81b34bb9d2683fe0.jpg (similarity: 0.6409)
#   → 5aa45db6c3fa456ab75d1fc1d50dbca0.jpg (similarity: 0.6409)
#   → b655ed3f26f940288a89ec89d67ebad9.jpg (similarity: 0.6408)
#   → 26a406f5e17c4dc1bfaa6576363e5c71.jpg (similarity: 0.6398)
#
# Query: 31d30d4d9e1a43799c3c91d4c9f9db4e.jpg
#   → b2d4d854428d4ea6aa8761e077a77339.jpg (similarity: 0.6591)
#   → 4d376e7797cd4796b5ffac4fed1cf609.jpg (similarity: 0.6369)
#   → 9a5992cc77ad48dea095cfd93790cd34.jpg (similarity: 0.6329)
#   → 5f902dfcee33489787a93d0d47ff19b2.jpg (similarity: 0.6210)
#   → 2fdffe8cb2064babb807fba2fbbc4eab.jpg (similarity: 0.6099)
#   → 5d201a49f13f4f81ac99d2b95dee08de.jpg (similarity: 0.5933)
#   → 2b47c9441a6541389da433e9f7182ae0.jpg (similarity: 0.5865)
#   → 7a3ac117a37a409b86c9417cf058ef3d.jpg (similarity: 0.5851)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.5842)
#   → 36d4bce2b813451db9c33958d77b4182.jpg (similarity: 0.5816)
#
# Query: 05116517952844eca09d257dc6bb8dd8.jpg
#   → 4d376e7797cd4796b5ffac4fed1cf609.jpg (similarity: 0.4873)
#   → e6f60a23d61e4a95babd05b93931eb02.jpg (similarity: 0.4854)
#   → 2fdffe8cb2064babb807fba2fbbc4eab.jpg (similarity: 0.4798)
#   → 07c664a8ee4c44d0bfb0b668f64b0ffb.jpg (similarity: 0.4779)
#   → d306e139a05c4b17bca41fae41c6eb56.jpg (similarity: 0.4670)
#   → c96f0ee291744158a14ffb75d2f29321.jpg (similarity: 0.4546)
#   → 326e4e826f584c42b4edfe7fa321cb88.jpg (similarity: 0.4451)
#   → e25c391c7f4b4fdfb743c7e13801d57b.jpg (similarity: 0.4447)
#   → 9b0e6a8f187a410cbb0424a44a8aef88.jpg (similarity: 0.4428)
#   → 6b90d38cf73f4ce499ccb44771e3b462.jpg (similarity: 0.4417)
#
# Query: 28f0daa49ba74288bf831deda5e04ed8.jpg
#   → 10924d813ab14685aac4a50f1620be32.jpg (similarity: 0.6359)
#   → 5a19e5ad8982482bbad923fea7ddb361.jpg (similarity: 0.6280)
#   → 7e40e171031049208804bdb3936b8bda.jpg (similarity: 0.6212)
#   → c13d64eb2dea4697a1710696eb5d2748.jpg (similarity: 0.6212)
#   → de47340e9beb4a1b872709bb6d05e4ca.jpg (similarity: 0.6164)
#   → fa3d2f9fbbb44ebda7b626634fd95a5b.jpg (similarity: 0.6146)
#   → bc625b320f934c3c91eea030d8dfd3ba.jpg (similarity: 0.6137)
#   → 6495a5d3dd784861ad2f5d80e2cbd90b.jpg (similarity: 0.6121)
#   → 5b7745181c054dd6b3409d4ec825c335.jpg (similarity: 0.6100)
#   → 844ad66bf3604ad6a3d6a7bb2433b30f.jpg (similarity: 0.6084)
#
# Query: edf608d086a14809a857bbf90ee4aa64.jpg
#   → a29ab68f6cdc4ba68eca29ca82eb716e.jpg (similarity: 0.6957)
#   → b4f25adb5daa4ecda29fefdace1fbf7e.jpg (similarity: 0.6879)
#   → 39159d7a30534f79a22e45c14db529e6.jpg (similarity: 0.6814)
#   → ffe2ca5e835147c985a5b046e9053c26.jpg (similarity: 0.6734)
#   → 82d4474b759344d1ad9961b9c79e325b.jpg (similarity: 0.6728)
#   → 3dd1c34588b2415bb74024a8b9b35d77.jpg (similarity: 0.6716)
#   → a2ea23aa344c4134b1ae5b34e42aa9e4.jpg (similarity: 0.6653)
#   → 3e8fbbd943a84c698afc69b685961bce.jpg (similarity: 0.6626)
#   → dcfc424adcb74dde95ac45dbf1937de4.jpg (similarity: 0.6593)
#   → 099334011ebd4351921d0b1228bc48e5.jpg (similarity: 0.6496)
#
# Query: fed14c06f2fd4c4a8664a09e400bc5e9.jpg
#   → 3dd1c34588b2415bb74024a8b9b35d77.jpg (similarity: 0.5317)
#   → 10924d813ab14685aac4a50f1620be32.jpg (similarity: 0.5310)
#   → 4b115fb236594790b891e5ef0fcc0fca.jpg (similarity: 0.5032)
#   → 39159d7a30534f79a22e45c14db529e6.jpg (similarity: 0.4956)
#   → 255be13815844aca9393ec2fdc6861ab.jpg (similarity: 0.4770)
#   → e96510e597214c808c0686db74d0a6e4.jpg (similarity: 0.4757)
#   → 92b60ca052904ed8b416b6f8f8b75216.jpg (similarity: 0.4753)
#   → 2d4ac420262247d9bff60c33a5340841.jpg (similarity: 0.4662)
#   → a5bad5611d0648ebb5518fc7ae0dcab5.jpg (similarity: 0.4659)
#   → 50c31597bfd64561b7d6650d19300077.jpg (similarity: 0.4642)
#
# Query: 0367b42f0e8742e9a4fb8aae462ae9dc.jpg
#   → 5f902dfcee33489787a93d0d47ff19b2.jpg (similarity: 0.6931)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.6837)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.6828)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.6727)
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.6726)
#   → f8f7b32e84dc4615979fbda2d9cc6bfb.jpg (similarity: 0.6663)
#   → b2d4d854428d4ea6aa8761e077a77339.jpg (similarity: 0.6415)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6372)
#   → ef586363b8914ea18c4142ce2eef95fe.jpg (similarity: 0.6311)
#   → 306150c25d8042daab0acba46dac6025.jpg (similarity: 0.6303)
#
# Query: accba42ccd8845a98ca6bb999a914760.jpg
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.6264)
#   → 2fdffe8cb2064babb807fba2fbbc4eab.jpg (similarity: 0.6260)
#   → 543f59153f0b493eb87f013534921bb5.jpg (similarity: 0.6246)
#   → 3c38b9025f3145b896507fd3cf57217e.jpg (similarity: 0.6152)
#   → 8a021c8126074a8c9b2afb9cf812b6e9.jpg (similarity: 0.6095)
#   → c8601b2a626143e3b30442901831c268.jpg (similarity: 0.5972)
#   → 9a5992cc77ad48dea095cfd93790cd34.jpg (similarity: 0.5966)
#   → e67b699998a0446eab846b82dbd7a094.jpg (similarity: 0.5927)
#   → 344e76a72bb843b4a9461e29b4778058.jpg (similarity: 0.5905)
#   → 974b76686b8b4687882f4ec7ae48904a.jpg (similarity: 0.5849)
#
# Query: 93bbb606b3024be7939213197f1cf2e7.jpg
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.7410)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.7138)
#   → 35e8624e2c31435ca232d9c2ab6a963c.jpg (similarity: 0.7090)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.6941)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6872)
#   → 0846c9fb262147adb410ddd029e4b646.jpg (similarity: 0.6581)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.6526)
#   → 8b11436b42864cfcaba961db4e6dfcd9.jpg (similarity: 0.6477)
#   → efbd498f5c7545d7a67e6f76e98c54e4.jpg (similarity: 0.6448)
#   → 0a400d67f9c24c5cb871e67b95af2280.jpg (similarity: 0.6432)
#
# Query: f40802a3ffd2499c971064a481c21c4f.jpg
#   → a2ea23aa344c4134b1ae5b34e42aa9e4.jpg (similarity: 0.8018)
# ...
#
# Query: 339c5c9f139648348b8c2b32b50aa3c3.jpg
#   → 5f902dfcee33489787a93d0d47ff19b2.jpg (similarity: 0.6336)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.6125)
#   → bc6a7f60881a44dda07f0e091cf8d288.jpg (similarity: 0.6041)
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.5966)
#   → 272e1e5125944ea9a8513074c3047c89.jpg (similarity: 0.5920)
#   → 449c60df60bd43e188e534b283661303.jpg (similarity: 0.5822)
#   → 4d376e7797cd4796b5ffac4fed1cf609.jpg (similarity: 0.5752)
#   → f8f7b32e84dc4615979fbda2d9cc6bfb.jpg (similarity: 0.5710)
#   → 79fae434508140409c9898300c7b6413.jpg (similarity: 0.5706)
#   → cc60dc2ddb95415aaaa46dfc476f4e9b.jpg (similarity: 0.5659)
#
# Query: 8e05c930e3ee43cfb1b3f27fe1e60efb.jpg
#   → 14011651632943ecaeac7f637c0c9ef1.jpg (similarity: 0.7148)
#   → 5fc8a73b015141b29527c922ce3fcdaa.jpg (similarity: 0.7127)
#   → e6b0d0c573e3458985700f0ccc1de105.jpg (similarity: 0.7125)
#   → 5839439c4a81436e81c291c8ffe222f4.jpg (similarity: 0.6957)
#   → 9b0e6a8f187a410cbb0424a44a8aef88.jpg (similarity: 0.6871)
#   → 2c12c04f580748c2a87107a876dd486c.jpg (similarity: 0.6855)
#   → 669a157b43464e64aadb8049a4cb025f.jpg (similarity: 0.6822)
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.6734)
#   → 8ef10f1b640e43e3890199303f32f03b.jpg (similarity: 0.6714)
#   → c9826268ea144f71b1ddb6449a897307.jpg (similarity: 0.6656)
#
# Query: be2d7a83eb564d2faad8dfe043ed9112.jpg
#   → bc6a7f60881a44dda07f0e091cf8d288.jpg (similarity: 0.6156)
#   → 449c60df60bd43e188e534b283661303.jpg (similarity: 0.5891)
#   → 42de4257d59f41a78803e6c9904f788c.jpg (similarity: 0.5731)
#   → 566cf7e9bfc941409e2c7121ee252bb8.jpg (similarity: 0.5611)
#   → 5fe55b528d8f4df480d33e04163bef2a.jpg (similarity: 0.5464)
#   → 4f6a3f8c9e8346d3ba8ef74a4c48b056.jpg (similarity: 0.5433)
#   → 576b62b9f236435cadfb2406edab09e3.jpg (similarity: 0.5392)
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.5358)
#   → 708d1afa4c3240f5873486a5f7489d5c.jpg (similarity: 0.5357)
#   → d8b312bdfa864076a1a3b32586ff1d0e.jpg (similarity: 0.5349)
#
# Query: 5ee9db6b17274a5597e48f7eaa0ccb4b.jpg
#   → 449c60df60bd43e188e534b283661303.jpg (similarity: 0.6681)
#   → 272e1e5125944ea9a8513074c3047c89.jpg (similarity: 0.5962)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.5956)
#   → a654dcca4bc54a7982196a9a85fe4f51.jpg (similarity: 0.5660)
#   → bc6a7f60881a44dda07f0e091cf8d288.jpg (similarity: 0.5614)
#   → 2794862196ed463fb5b2a6bde29be065.jpg (similarity: 0.5610)
#   → 6965322d08d0494591cd9237ee8ded00.jpg (similarity: 0.5564)
#   → b2d4d854428d4ea6aa8761e077a77339.jpg (similarity: 0.5564)
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.5558)
#   → 50a45e63e946442fa3a0b6efc8a5a73a.jpg (similarity: 0.5542)
#
# Query: e5278001bcb44606a00c6824dd2700c0.jpg
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.7535)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.7273)
#   → 35e8624e2c31435ca232d9c2ab6a963c.jpg (similarity: 0.7081)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.6992)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.6817)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6740)
#   → efbd498f5c7545d7a67e6f76e98c54e4.jpg (similarity: 0.6686)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.6557)
#   → 0a400d67f9c24c5cb871e67b95af2280.jpg (similarity: 0.6478)
#   → 0846c9fb262147adb410ddd029e4b646.jpg (similarity: 0.6476)
#
# Query: 62e2b3a6cb264d399d47f1f0437f4466.jpg
#   → 9ace16e6eb6947a0a0d5f245743a37fc.jpg (similarity: 0.4677)
#   → da66a204915e4e7fb878da99a0aaa7e5.jpg (similarity: 0.4471)
#   → 899ebcdfdeec42378e485aad03c3c2d9.jpg (similarity: 0.4331)
#   → 50a45e63e946442fa3a0b6efc8a5a73a.jpg (similarity: 0.4268)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.4233)
#   → 3c38b9025f3145b896507fd3cf57217e.jpg (similarity: 0.4161)
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.4160)
#   → df7a8c8c21af446381347972386521a1.jpg (similarity: 0.4139)
#   → 43ca0f3893594535b6bc19e9de3fd259.jpg (similarity: 0.4103)
#   → d306e139a05c4b17bca41fae41c6eb56.jpg (similarity: 0.4081)
#
# Query: 597954a7328c44348d9d01d6bcc7bd6c.jpg
#   → 255be13815844aca9393ec2fdc6861ab.jpg (similarity: 0.6748)
#   → b81efa26a9e643028b5c3d8a0727e74b.jpg (similarity: 0.6654)
#   → 7e39906b7a0040119df355667929a4c0.jpg (similarity: 0.6586)
#   → 3e8fbbd943a84c698afc69b685961bce.jpg (similarity: 0.6472)
#   → 10924d813ab14685aac4a50f1620be32.jpg (similarity: 0.6381)
#   → de47340e9beb4a1b872709bb6d05e4ca.jpg (similarity: 0.6352)
#   → 0416b7f2fcb34b19893444e50f88ba3b.jpg (similarity: 0.6346)
#   → a2ea23aa344c4134b1ae5b34e42aa9e4.jpg (similarity: 0.6343)
#   → 4a050c59736740599b570773a6e8c7e9.jpg (similarity: 0.6332)
#   → f0c0b95cdac4476baf9eb270c582f7cf.jpg (similarity: 0.6328)
#
# Query: f217e8621fd24949bad43a6efc167dcb.jpg
#   → 39159d7a30534f79a22e45c14db529e6.jpg (similarity: 0.6423)
#   → 5249b4453c704cfc83c8186773674c98.jpg (similarity: 0.6367)
#   → 63ec70d7ba8747aea2bede2320213508.jpg (similarity: 0.6317)
#   → 14a2384533574cbb96af580332ef71b3.jpg (similarity: 0.6311)
#   → 1465aa99754d4c8cae68e2d70ac2fe87.jpg (similarity: 0.6283)
#   → 1db791bd08394b0f892a5490ec3546f0.jpg (similarity: 0.6264)
#   → 252df13e334746f29e395511e327935c.jpg (similarity: 0.6189)
#   → 53948387e8aa4cab86f874d65f5246fd.jpg (similarity: 0.6177)
#   → 65201fae19ac4404b660e9c965422eec.jpg (similarity: 0.6155)
#   → bc22cee99d1147b8ba305792a1e902db.jpg (similarity: 0.6151)
#
# Query: f3ec852c2fc3431b99e24d710bf4d202.jpg
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.7651)
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.7198)
#   → 272e1e5125944ea9a8513074c3047c89.jpg (similarity: 0.7032)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6957)
#   → 747a83fa3bf74542a947fcf4ae547eb3.jpg (similarity: 0.6908)
#   → ef586363b8914ea18c4142ce2eef95fe.jpg (similarity: 0.6834)
#   → 5f902dfcee33489787a93d0d47ff19b2.jpg (similarity: 0.6819)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.6819)
#   → 6e1fd42f80474defb740ff40638a119f.jpg (similarity: 0.6773)
#   → 8b11436b42864cfcaba961db4e6dfcd9.jpg (similarity: 0.6691)
#
# Query: c3688fe0e00d4615bdad9d6840c5e53d.jpg
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.7083)
#   → 272e1e5125944ea9a8513074c3047c89.jpg (similarity: 0.6921)
#   → 7c3f3cae7dbd481191f246c6502b8607.jpg (similarity: 0.6834)
#   → 3e16c04505d94bee99c53e80af01956f.jpg (similarity: 0.6642)
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.6617)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6586)
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.6504)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.6398)
#   → 449c60df60bd43e188e534b283661303.jpg (similarity: 0.6360)
#   → e67b699998a0446eab846b82dbd7a094.jpg (similarity: 0.6339)
#
# Query: 741ae31aa8e74b4b9977492797a8351d.jpg
#   → 1e537a3e2eb74086a6ca10863f74f7f2.jpg (similarity: 0.6518)
#   → 252df13e334746f29e395511e327935c.jpg (similarity: 0.6238)
#   → 5b47da4c1e0c4d24a9f5bb8d3afc26cb.jpg (similarity: 0.5970)
#   → d0926b126e744e71aba05609563290ac.jpg (similarity: 0.5899)
#   → 859cac6783564c9b8c99004e4542f941.jpg (similarity: 0.5812)
#   → 64c047c043ff45d2b9cc035e79d8630e.jpg (similarity: 0.5793)
#   → 5249b4453c704cfc83c8186773674c98.jpg (similarity: 0.5772)
#   → 5c15dbdd21b54ebdb6faf8a681dc11c9.jpg (similarity: 0.5767)
#   → 9b11fb1728164d92aeea1b9c61c8a020.jpg (similarity: 0.5760)
#   → 9a5992cc77ad48dea095cfd93790cd34.jpg (similarity: 0.5753)
#
# Query: 53cafc7238f24fee915b73e80416eff2.jpg
#   → a5bad5611d0648ebb5518fc7ae0dcab5.jpg (similarity: 0.6863)
#   → 8a5de1abd9e24b3b855901bc5fd813a1.jpg (similarity: 0.6724)
#   → f53cf3f6ae5e46b9be619b0cd4151cd7.jpg (similarity: 0.6719)
#   → c13d64eb2dea4697a1710696eb5d2748.jpg (similarity: 0.6704)
#   → 10924d813ab14685aac4a50f1620be32.jpg (similarity: 0.6648)
#   → c176fa2940224efc9e3a657d09cb6dbc.jpg (similarity: 0.6613)
#   → 73a2379de5734bfd8243677a9e96cf57.jpg (similarity: 0.6543)
#   → a2ea23aa344c4134b1ae5b34e42aa9e4.jpg (similarity: 0.6543)
#   → c834fcdf7e0d4810a61390a7cc956e95.jpg (similarity: 0.6534)
#   → 6495a5d3dd784861ad2f5d80e2cbd90b.jpg (similarity: 0.6511)
#
# Query: 0d8be3c646394478a5f2b52bdca4414b.jpg
#   → c244787d0adf41f5b5cc255c3ba67652.jpg (similarity: 0.6040)
#   → 10924d813ab14685aac4a50f1620be32.jpg (similarity: 0.5918)
#   → ba4a48eeab94476693cc02231102ba04.jpg (similarity: 0.5687)
#   → 7f39239e614a40b09cccf6ed57f6f1aa.jpg (similarity: 0.5640)
#   → c59455f9636b498593840935af865abe.jpg (similarity: 0.5629)
#   → 7d892ae4dcf2432daaad2048b9318235.jpg (similarity: 0.5628)
#   → 81dcca6e51694385b9eb96aac08fc690.jpg (similarity: 0.5580)
#   → 625c897089ce479896e6b29b4c56b3b3.jpg (similarity: 0.5555)
#   → 9a5992cc77ad48dea095cfd93790cd34.jpg (similarity: 0.5507)
#   → 8a5de1abd9e24b3b855901bc5fd813a1.jpg (similarity: 0.5456)
#
# Query: dcfac934ae1740d786afc380aa982bca.jpg
#   → 049b584b3af9408493b432cfd9cba577.jpg (similarity: 0.6924)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.6691)
#   → 306150c25d8042daab0acba46dac6025.jpg (similarity: 0.6677)
#   → 153595449fb448b2882e8765d75a9fa6.jpg (similarity: 0.6662)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6657)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.6643)
#   → 8b11436b42864cfcaba961db4e6dfcd9.jpg (similarity: 0.6637)
#   → 4f6a3f8c9e8346d3ba8ef74a4c48b056.jpg (similarity: 0.6509)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6388)
#   → 0a3195260ab54d7f83c5ebff96b8a934.jpg (similarity: 0.6344)
#
# Query: 4ca6003e0c0640d887cbd203838fd2f9.jpg
#   → de47340e9beb4a1b872709bb6d05e4ca.jpg (similarity: 0.7062)
#   → 6495a5d3dd784861ad2f5d80e2cbd90b.jpg (similarity: 0.6773)
#   → 5c6d0763bba14ebbb70b60d514c5a8b9.jpg (similarity: 0.6662)
#   → 7e40e171031049208804bdb3936b8bda.jpg (similarity: 0.6639)
#   → b4f25adb5daa4ecda29fefdace1fbf7e.jpg (similarity: 0.6577)
#   → bd585232e2084ba38091df4260bc096e.jpg (similarity: 0.6543)
#   → 252df13e334746f29e395511e327935c.jpg (similarity: 0.6539)
#   → 39159d7a30534f79a22e45c14db529e6.jpg (similarity: 0.6523)
#   → 255be13815844aca9393ec2fdc6861ab.jpg (similarity: 0.6503)
#   → c13d64eb2dea4697a1710696eb5d2748.jpg (similarity: 0.6457)
#
# Query: 60df2d27458149518e060c4af6471e79.jpg
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.6996)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6754)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.6392)
#   → 55987960e55541a983778be2751145e0.jpg (similarity: 0.6383)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.6278)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6219)
#   → f8f7b32e84dc4615979fbda2d9cc6bfb.jpg (similarity: 0.6183)
#   → 8b11436b42864cfcaba961db4e6dfcd9.jpg (similarity: 0.6178)
#   → 35e8624e2c31435ca232d9c2ab6a963c.jpg (similarity: 0.6006)
#   → 50a45e63e946442fa3a0b6efc8a5a73a.jpg (similarity: 0.5913)
#
# Query: 48f23e32efc5439c96151806333353db.jpg
#   → a912219187564c9fbadb37efebdf9eaa.jpg (similarity: 0.6196)
#   → 3e8fbbd943a84c698afc69b685961bce.jpg (similarity: 0.6158)
#   → 255be13815844aca9393ec2fdc6861ab.jpg (similarity: 0.6066)
#   → 099334011ebd4351921d0b1228bc48e5.jpg (similarity: 0.6035)
#   → 7d892ae4dcf2432daaad2048b9318235.jpg (similarity: 0.6024)
#   → 7b22cba2fbbe45e8ab131ea2f440f46b.jpg (similarity: 0.6013)
#   → a29ab68f6cdc4ba68eca29ca82eb716e.jpg (similarity: 0.6009)
#   → 50c31597bfd64561b7d6650d19300077.jpg (similarity: 0.5984)
#   → a2ea23aa344c4134b1ae5b34e42aa9e4.jpg (similarity: 0.5937)
#   → ffe2ca5e835147c985a5b046e9053c26.jpg (similarity: 0.5933)
#
# Query: 1a851b269e0e43c9876b8ee98f8add92.jpg
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.6491)
#   → ef586363b8914ea18c4142ce2eef95fe.jpg (similarity: 0.6279)
#   → 747a83fa3bf74542a947fcf4ae547eb3.jpg (similarity: 0.6277)
#   → 4b0e25833ad64aca8705fc305c8b705b.jpg (similarity: 0.6158)
#   → c010ab8acc8a447685cd9c279ebd693c.jpg (similarity: 0.5819)
#   → 14011651632943ecaeac7f637c0c9ef1.jpg (similarity: 0.5810)
#   → 0a1b8c413c3d4484a3451ce93ee97cd0.jpg (similarity: 0.5785)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.5746)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.5716)
#   → 5f902dfcee33489787a93d0d47ff19b2.jpg (similarity: 0.5667)
#
# Query: e6dded146f024e71a543108f39529203.jpg
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.7075)
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.7012)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.6768)
#   → 272e1e5125944ea9a8513074c3047c89.jpg (similarity: 0.6553)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.6408)
#   → ded232818846450eb3cd96cbbf12d8d6.jpg (similarity: 0.6404)
#   → 2bd9978849fc4561ab7f322e3bfbbd83.jpg (similarity: 0.6231)
#   → bc6a7f60881a44dda07f0e091cf8d288.jpg (similarity: 0.6154)
#   → 79fae434508140409c9898300c7b6413.jpg (similarity: 0.6101)
#   → 3e16c04505d94bee99c53e80af01956f.jpg (similarity: 0.6018)
#
# Query: ecac32d299314af2aeb5e7916eb24876.jpg
#   → 5f902dfcee33489787a93d0d47ff19b2.jpg (similarity: 0.6135)
#   → 9b0e6a8f187a410cbb0424a44a8aef88.jpg (similarity: 0.6116)
#   → 4d376e7797cd4796b5ffac4fed1cf609.jpg (similarity: 0.6112)
#   → c010ab8acc8a447685cd9c279ebd693c.jpg (similarity: 0.5909)
#   → 33d6d48024e24657b667d5ec7827a836.jpg (similarity: 0.5885)
#   → 8ef10f1b640e43e3890199303f32f03b.jpg (similarity: 0.5743)
#   → 17b4c3aaf1aa47d094219ce38f5c082d.jpg (similarity: 0.5716)
#   → 153595449fb448b2882e8765d75a9fa6.jpg (similarity: 0.5710)
#   → f2b59f134ca847e080b7537e73933ed5.jpg (similarity: 0.5701)
#   → ecb9847d34c14a7f9e24b86ad5783325.jpg (similarity: 0.5689)
#
# Query: d9026ecadd1d487a9b07911564e1e0e8.jpg
#   → 543f59153f0b493eb87f013534921bb5.jpg (similarity: 0.7166)
#   → 449c60df60bd43e188e534b283661303.jpg (similarity: 0.6696)
#   → 708d1afa4c3240f5873486a5f7489d5c.jpg (similarity: 0.6596)
#   → 15c94aaa148142b28ab57712e6377450.jpg (similarity: 0.6430)
#   → 1737f3015d3d4814bfe46aa6a6298a5e.jpg (similarity: 0.6237)
#   → a654dcca4bc54a7982196a9a85fe4f51.jpg (similarity: 0.6233)
#   → d4baec95ab8443be8622a8b6424c4621.jpg (similarity: 0.6223)
#   → 365066184b83492fabaa9acc5ca243ab.jpg (similarity: 0.6218)
#   → e41584849e7246b0b893deceab68eb97.jpg (similarity: 0.6168)
#   → 3c38b9025f3145b896507fd3cf57217e.jpg (similarity: 0.6090)
#
# Query: 4d90f0ff878543e1b316243c21048968.jpg
#   → 7e40e171031049208804bdb3936b8bda.jpg (similarity: 0.7119)
#   → bc22cee99d1147b8ba305792a1e902db.jpg (similarity: 0.6973)
#   → 859cac6783564c9b8c99004e4542f941.jpg (similarity: 0.6909)
#   → bc625b320f934c3c91eea030d8dfd3ba.jpg (similarity: 0.6779)
#   → 6495a5d3dd784861ad2f5d80e2cbd90b.jpg (similarity: 0.6638)
#   → ad4c283fc3204ede88de7baf92aa45e8.jpg (similarity: 0.6492)
#   → cc74780f276f423aa446e8ee778aa192.jpg (similarity: 0.6443)
#   → 9b11fb1728164d92aeea1b9c61c8a020.jpg (similarity: 0.6430)
#   → beda8d60bf3d4f809c4992244dbf9c49.jpg (similarity: 0.6428)
#   → c13d64eb2dea4697a1710696eb5d2748.jpg (similarity: 0.6329)
#
# Query: 0d011347f52c4b5f843b5763846169f9.jpg
#   → e2bc5521d7374eeeb233df03c814fa2a.jpg (similarity: 0.6643)
#   → 60deaa5529ae4f899d34f4accbb11661.jpg (similarity: 0.6441)
#   → a75d79ce216f4c838eef372406848f14.jpg (similarity: 0.6438)
#   → 55987960e55541a983778be2751145e0.jpg (similarity: 0.6422)
#   → 225e33d1f0764943a6e88f880da423cc.jpg (similarity: 0.6177)
#   → 940060c64fdb4881ac7d008bf33e4afb.jpg (similarity: 0.5808)
#   → 9f2e65949b644b859d3383bac0028f86.jpg (similarity: 0.5805)
#   → 826698e69ad843ddafe18fadeaae1091.jpg (similarity: 0.5730)
#   → 53ed19d60e5948168bb14e11d04ce7c5.jpg (similarity: 0.5700)
#   → bc6a7f60881a44dda07f0e091cf8d288.jpg (similarity: 0.5671)
#
# Query: d67fb862a2b7438ea14bb32528a5867a.jpg
#   → 7e39906b7a0040119df355667929a4c0.jpg (similarity: 0.6454)
#   → de47340e9beb4a1b872709bb6d05e4ca.jpg (similarity: 0.6261)
#   → 3d79d08c03e54d9b934c3bf95949be32.jpg (similarity: 0.5994)
#   → 4f955f59290f4088a5c117c007c93e40.jpg (similarity: 0.5977)
#   → 9a5992cc77ad48dea095cfd93790cd34.jpg (similarity: 0.5916)
#   → 3e8fbbd943a84c698afc69b685961bce.jpg (similarity: 0.5905)
#   → 39159d7a30534f79a22e45c14db529e6.jpg (similarity: 0.5780)
#   → 255be13815844aca9393ec2fdc6861ab.jpg (similarity: 0.5759)
#   → 84cb8a2bd97945849cf89eb9ebe8bd73.jpg (similarity: 0.5704)
#   → e67b699998a0446eab846b82dbd7a094.jpg (similarity: 0.5703)

# %%
len(submission['00502e372bc846c2b8d52780e5387587.jpg'])
# Out:
# 10

# %% [markdown]
# # Submit

# %%
from utils.submit import submit

# %%
submit(submission, groupname='Overfit & Underpaid', url='http://tatooine.disi.unitn.it:3001/retrieval/')
# Out:
# accuracy is 33.74570446735395
